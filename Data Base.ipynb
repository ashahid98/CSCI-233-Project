# %%
import sqlite3
conn = sqlite3.connect('air.db')

# %%
c = conn.cursor()

# %%
c.execute("select * from airr")

# %%
import csv_to_sqlite

# %%
from pathlib import Path

# %%
Path('air.db').touch()

# %%
import pandas as pd

# %%
asthma = pd.read_csv('/Applications/ast.csv')

# %%
asthma.to_sql('ast', conn, if_exists='append', index = False)

c.execute('''SELECT * FROM ast''').fetchall()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
# [('Bronx: Crotona - Tremont',
#   'Fine Particulate Matter (PM2.5)',
#   8.2,
#   '0 to 17 years',
#   '3,161'),
#  ('Bronx: Fordham - Bronx Pk',
#   'Fine Particulate Matter (PM2.5)',
#   7.6,
#   '0 to 17 years',
#   '3,120'),
#  ('Bronx: High Bridge - Morrisania',
#   'Fine Particulate Matter (PM2.5)',
#   8.2,
#   '0 to 17 years',
#   '3,559'),
#  ('Bronx: Hunts Point - Mott Haven',
#   'Fine Particulate Matter (PM2.5)',
#   8.3,
#   '0 to 17 years',
#   '2,486'),
#  ('Bronx: Kingsbridge - Riverdale',
#   'Fine Particulate Matter (PM2.5)',
#   7.5,
#   '0 to 17 years',
#   '336'),
#  ('Bronx: Northeast Bronx',
#   'Fine Particulate Matter (PM2.5)',
#   7.5,
#   '0 to 17 years',
#   '1,467'),
#  ('Bronx: Pelham - Throgs Neck',
# ...

# %%
asthma.head()
# Out:
#                          Geography            Air Quality Indicator  \
# 0         Bronx: Crotona - Tremont  Fine Particulate Matter (PM2.5)
# 1        Bronx: Fordham - Bronx Pk  Fine Particulate Matter (PM2.5)
# 2  Bronx: High Bridge - Morrisania  Fine Particulate Matter (PM2.5)
# 3  Bronx: Hunts Point - Mott Haven  Fine Particulate Matter (PM2.5)
# 4   Bronx: Kingsbridge - Riverdale  Fine Particulate Matter (PM2.5)
#
#    Mean, mcg per cubic meter     Age Group  Asthma ER visits
# 0                        8.2  0 to 17 years            3,161
# 1                        7.6  0 to 17 years            3,120
# 2                        8.2  0 to 17 years            3,559
# 3                        8.3  0 to 17 years            2,486
# 4                        7.5  0 to 17 years              336
