# %%
import csv_to_sqlite
from pathlib import Path
Path('air.db').touch()
import pandas as pd
#asthma = pd.read_csv("Asthma & Air Quality Data.csv")
#asthma.to_sql('final', conn, if_exists='append', index = False)

#d = c.execute('''SELECT * FROM final''').fetchall()

from sqlalchemy import create_engine 
  
# SQLAlchemy connectable 
cnx = create_engine('sqlite:///air.db').connect() 
  
# table named 'contacts' will be returned as a dataframe. 
df = pd.read_sql_table('final', 'sqlite:///air.db')
df['AsthmaERVisits']=df['AsthmaERVisits'].str.replace(',','')
df['AsthmaERVisits'] = df['AsthmaERVisits'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geography-UHF42       42 non-null     object
#  1   AirQualityIndicator   42 non-null     object
#  2   Meanmcgpercubicmeter  42 non-null     int64
#  3   AgeGroup              42 non-null     object
#  4   AsthmaERVisits        42 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.8+ KB

# %%
import json
import pandas as pd
import geopandas as gpd
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure, output_file, save
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
from bokeh.palettes import brewer

# %%
dfr = gpd.read_file('uhf42.geojson')
print(dfr)
# Out:
#     cartodb_id  objectid        borough                             uhf_neigh  \
# 0            1         1            N/A                                  None
# 1            5         5          Bronx                  Pelham - Throgs Neck
# 2           18        18       Brooklyn         Coney Island - Sheepshead Bay
# 3           32        32         Queens                  Flushing - Clearview
# 4           37        37         Queens                               Jamaica
# 5           38        38         Queens                      Southeast Queens
# 6           43        43  Staten Island             South Beach - Tottenville
# 7           39        39         Queens                              Rockaway
# 8           24        24      Manhattan                       Upper East Side
# 9           27        27      Manhattan              Greenwich Village - Soho
# 10          30        30         Queens            Long Island City - Astoria
# 11          35        35         Queens                         Fresh Meadows
# 12           2         2          Bronx               Kingsbridge - Riverdale
# 13          14        14       Brooklyn                          Borough Park
# 14           3         3          Bronx                       Northeast Bronx
# 15           4         4          Bronx                  Fordham - Bronx Park
# 16           6         6          Bronx                     Crotona - Tremont
# 17           7         7          Bronx              High Bridge - Morrisania
# 18          11        11       Brooklyn    Bedford Stuyvesant - Crown Heights
# 19           8         8          Bronx              Hunts Point - Mott Haven
# 20           9         9       Brooklyn                            Greenpoint
# 21          10        10       Brooklyn           Downtown  - Heights - Slope
# 22          12        12       Brooklyn                         East New York
# 23          13        13       Brooklyn                           Sunset Park
# 24          15        15       Brooklyn              East Flatbush - Flatbush
# 25          16        16       Brooklyn                  Canarsie - Flatlands
# 26          17        17       Brooklyn               Bensonhurst - Bay Ridge
# 27          19        19       Brooklyn               Williamsburg - Bushwick
# 28          20        20      Manhattan           Washington Heights - Inwood
# 29          21        21      Manhattan  Central Harlem - Morningside Heights
# 30          22        22      Manhattan                           East Harlem
# 31          23        23      Manhattan                       Upper West Side
# 32          25        25      Manhattan                     Chelsea - Clinton
# 33          26        26      Manhattan          Gramercy Park -  Murray Hill
# 34          28        28      Manhattan        Union Square - Lower East Side
# 35          29        29      Manhattan                       Lower Manhattan
# 36          31        31         Queens                           West Queens
# 37          33        33         Queens                 Bayside - Little Neck
# 38          34        34         Queens              Ridgewood - Forest Hills
# 16  MULTIPOLYGON (((-73.91444 40.85978, -73.91328 ...
# 17  MULTIPOLYGON (((-73.91439 40.84645, -73.91482 ...
# 18  MULTIPOLYGON (((-73.94506 40.68910, -73.94491 ...
# 19  MULTIPOLYGON (((-73.89216 40.83364, -73.89173 ...
# 20  MULTIPOLYGON (((-73.92436 40.71557, -73.92404 ...
# 21  MULTIPOLYGON (((-73.97022 40.70673, -73.97018 ...
# 22  MULTIPOLYGON (((-73.86651 40.68447, -73.86630 ...
# 23  MULTIPOLYGON (((-73.99924 40.67073, -74.00017 ...
# 24  MULTIPOLYGON (((-73.96290 40.66380, -73.96243 ...
# 25  MULTIPOLYGON (((-73.89860 40.65583, -73.89800 ...
# 26  MULTIPOLYGON (((-74.01695 40.63056, -74.01729 ...
# 27  MULTIPOLYGON (((-73.92633 40.71404, -73.92453 ...
# 28  MULTIPOLYGON (((-73.92346 40.85186, -73.92460 ...
# 29  MULTIPOLYGON (((-73.93431 40.82431, -73.93408 ...
# 30  MULTIPOLYGON (((-73.91930 40.79919, -73.91908 ...
# 31  MULTIPOLYGON (((-73.96485 40.80671, -73.96201 ...
# 32  MULTIPOLYGON (((-73.99334 40.77273, -73.99065 ...
# 33  MULTIPOLYGON (((-73.96389 40.75209, -73.96717 ...
# 34  MULTIPOLYGON (((-73.98977 40.73918, -73.98771 ...
# 35  MULTIPOLYGON (((-74.01627 40.69326, -74.01440 ...
# 36  MULTIPOLYGON (((-73.88806 40.76831, -73.88773 ...
# 37  MULTIPOLYGON (((-73.73499 40.77303, -73.73399 ...
# 38  MULTIPOLYGON (((-73.84418 40.73426, -73.84397 ...
# 39  MULTIPOLYGON (((-73.85616 40.65058, -73.85665 ...
# 40  MULTIPOLYGON (((-74.10785 40.64582, -74.10780 ...
# 41  MULTIPOLYGON (((-74.07793 40.64902, -74.07627 ...
# 42  MULTIPOLYGON (((-74.20077 40.61423, -74.19913 ...

# %%
#Change the data type and column name to match the geojson file 
#df['Geography-UHF42'] = df['Geography-UHF42'].astype(str)
df.rename(index=str, columns={'Geography-UHF42': 'uhf_neigh'}, inplace=True)
#Turn the GeoJson file into a data frame and merge it with df 
data = 'uhf42.geojson'
dfr = gpd.read_file(data)
merge = dfr.merge(df, how='left', on='uhf_neigh')
merge.fillna('No data', inplace = True)
#Turn the merged data frame back into a json file  
merged_json = json.loads(merge.to_json())
json_data = json.dumps(merged_json)
#geosource - GeoJSONDataSource(geojson = json_data)

print(merge)
# Out:
#     cartodb_id  objectid        borough                             uhf_neigh  \
# 0            1         1            N/A                               No data
# 1            5         5          Bronx                  Pelham - Throgs Neck
# 2           18        18       Brooklyn         Coney Island - Sheepshead Bay
# 3           32        32         Queens                  Flushing - Clearview
# 4           37        37         Queens                               Jamaica
# 5           38        38         Queens                      Southeast Queens
# 6           43        43  Staten Island             South Beach - Tottenville
# 7           39        39         Queens                              Rockaway
# 8           24        24      Manhattan                       Upper East Side
# 9           27        27      Manhattan              Greenwich Village - Soho
# 10          30        30         Queens            Long Island City - Astoria
# 11          35        35         Queens                         Fresh Meadows
# 38  2.652703e+08   87164.991021      405
# 39  2.725265e+08  123610.729914      407
# 40  1.645195e+08   86322.590205      501
# 41  3.272437e+08  107053.886650      502
# 42  4.131080e+08  117827.805092      503
#
#                                              geometry  \
# 0   MULTIPOLYGON (((-73.75347 40.61046, -73.75491 ...
# 1   MULTIPOLYGON (((-73.88141 40.81799, -73.88141 ...
# 2   MULTIPOLYGON (((-73.93935 40.61019, -73.93754 ...
# 3   MULTIPOLYGON (((-73.83935 40.76506, -73.83934 ...
# 4   MULTIPOLYGON (((-73.75791 40.65089, -73.75771 ...
# 5   MULTIPOLYGON (((-73.71345 40.75961, -73.71331 ...
# 6   MULTIPOLYGON (((-74.20516 40.57365, -74.20770 ...
# 7   MULTIPOLYGON (((-73.76702 40.61422, -73.76520 ...
# 8   MULTIPOLYGON (((-73.95990 40.75056, -73.96158 ...
# 9   MULTIPOLYGON (((-74.01227 40.74287, -74.00933 ...
# 10  MULTIPOLYGON (((-73.90387 40.77891, -73.90347 ...
# 11  MULTIPOLYGON (((-73.77831 40.74874, -73.77755 ...
# 12  MULTIPOLYGON (((-73.87793 40.90556, -73.87859 ...
# 13  MULTIPOLYGON (((-73.97379 40.65639, -73.97355 ...
# 14  MULTIPOLYGON (((-73.85253 40.90985, -73.85235 ...
# 15  MULTIPOLYGON (((-73.85627 40.88315, -73.85666 ...
# 16  MULTIPOLYGON (((-73.91444 40.85978, -73.91328 ...
# 17  MULTIPOLYGON (((-73.91439 40.84645, -73.91482 ...
# 18  MULTIPOLYGON (((-73.94506 40.68910, -73.94491 ...
# 19  MULTIPOLYGON (((-73.89216 40.83364, -73.89173 ...
# 20  MULTIPOLYGON (((-73.92436 40.71557, -73.92404 ...
# 21  MULTIPOLYGON (((-73.97022 40.70673, -73.97018 ...
# 22  MULTIPOLYGON (((-73.86651 40.68447, -73.86630 ...
# 23  MULTIPOLYGON (((-73.99924 40.67073, -74.00017 ...
# 24  MULTIPOLYGON (((-73.96290 40.66380, -73.96243 ...
# 25  MULTIPOLYGON (((-73.89860 40.65583, -73.89800 ...
# 26  MULTIPOLYGON (((-74.01695 40.63056, -74.01729 ...
# 27  MULTIPOLYGON (((-73.92633 40.71404, -73.92453 ...
# 28  MULTIPOLYGON (((-73.92346 40.85186, -73.92460 ...
# 29  MULTIPOLYGON (((-73.93431 40.82431, -73.93408 ...
# 30  MULTIPOLYGON (((-73.91930 40.79919, -73.91908 ...
# 31  MULTIPOLYGON (((-73.96485 40.80671, -73.96201 ...
# 32  MULTIPOLYGON (((-73.99334 40.77273, -73.99065 ...
# 33  MULTIPOLYGON (((-73.96389 40.75209, -73.96717 ...
# 34  MULTIPOLYGON (((-73.98977 40.73918, -73.98771 ...
# 35  MULTIPOLYGON (((-74.01627 40.69326, -74.01440 ...
# 36  MULTIPOLYGON (((-73.88806 40.76831, -73.88773 ...
# 37  MULTIPOLYGON (((-73.73499 40.77303, -73.73399 ...
# 38  MULTIPOLYGON (((-73.84418 40.73426, -73.84397 ...
# 39  MULTIPOLYGON (((-73.85616 40.65058, -73.85665 ...
# 40  MULTIPOLYGON (((-74.10785 40.64582, -74.10780 ...
# 41  MULTIPOLYGON (((-74.07793 40.64902, -74.07627 ...
# 42  MULTIPOLYGON (((-74.20077 40.61423, -74.19913 ...
#
#                 AirQualityIndicator Meanmcgpercubicmeter       AgeGroup  \
# 0                           No data              No data        No data
# 1   Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 2   Fine Particulate Matter (PM2.5)                    6  0 to 17 years
# 3                           No data              No data        No data
# 4   Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 5   Fine Particulate Matter (PM2.5)                    6  0 to 17 years
# 6   Fine Particulate Matter (PM2.5)                    6  0 to 17 years
# 7                           No data              No data        No data
# 8   Fine Particulate Matter (PM2.5)                    9  0 to 17 years
# 9                           No data              No data        No data
# 10  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 11  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 12  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 13  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 14  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 15                          No data              No data        No data
# 16  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 17  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 18  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 19  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 20  Fine Particulate Matter (PM2.5)                    9  0 to 17 years
# 21                          No data              No data        No data
# 22  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 23  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 24  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 25  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 26  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 27  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 28                          No data              No data        No data
# 29  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 30  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 31  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 32  Fine Particulate Matter (PM2.5)                   10  0 to 17 years
# 33                          No data              No data        No data
# 34  Fine Particulate Matter (PM2.5)                    9  0 to 17 years
# 35  Fine Particulate Matter (PM2.5)                    9  0 to 17 years
# 36  Fine Particulate Matter (PM2.5)                    8  0 to 17 years
# 37  Fine Particulate Matter (PM2.5)                    6  0 to 17 years
# 38  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 39  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
# 40                          No data              No data        No data
# 41  Fine Particulate Matter (PM2.5)                    6  0 to 17 years
# 42  Fine Particulate Matter (PM2.5)                    7  0 to 17 years
#
#    AsthmaERVisits
# 0         No data
# 1            2356
# 2             553
# 3         No data
# 4            1534
# 5             507
# 6             159
# 7         No data
# 8             161
# 9         No data
# 10            423
# 11            242
# 12            336
# 13            522
# 14           1467
# 15        No data
# 16           3161
# 17           3559
# 18           2941
# 19           2486
# 20            263
# 21        No data
# 22           2020
# 23            334
# 24           1770
# 25            889
# 26            237
# 27           1899
# 28        No data
# 29           2042
# 30           1445
# 31            458
# 32            173
# 33        No data
# 34            643
# 35             95
# 36           1771
# 37             52
# 38            494
# 39            917
# 40        No data
# 41            387
# 42             93

# %%
geosource = GeoJSONDataSource(geojson = json_data)
#set the color palette 
palette = brewer['Blues'][8]
palette = palette[::-1]
color_mapper = LinearColorMapper(palette = palette, low = 0, high = 4000,  nan_color = '#d9d9d9')
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
border_line_color='black',location = (0,0), orientation ='horizontal')
#Set the size and title of the graph
p = figure(title = 'Asthma ER Visits and Air Quality', plot_height = 700 , plot_width = 700, toolbar_location = None, 
          tooltips=[
         ("Borough", "@borough"),     
         ("Neighborhood", "@uhf_neigh"),
         ("Air Quality", "@Meanmcgpercubicmeter"),
         ("Asthma ER Visits","@AsthmaERVisits")])
#Makes it so there are no grid lines
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.patches('xs','ys', source = geosource,fill_color = {'field'     :'AsthmaERVisits', 'transform' : color_mapper},
         line_color = 'black', line_width = 0.25, fill_alpha = 1)
p.add_layout(color_bar, 'below')
output_file("asthmamap.html")
save(p)
# Out:
# 'C:\\Users\\Diana\\Desktop\\asthmamap.html'
